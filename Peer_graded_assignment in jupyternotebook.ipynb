# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Ugwuonu, Dennis Chinonso

# %% [markdown]
# Data Scientist

# %% [markdown]
# ##### I am interested in data science because I want to do something that will give relevance to mathematics. I love mathematic and I want to do it on the computer, and data science gives me that platform.

# %% [markdown]
# ### The following code sums two integers

# %%
2 + 4
# Out:
# 6

# %% [markdown]
# www.ibm.com
